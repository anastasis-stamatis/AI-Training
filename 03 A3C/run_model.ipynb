# %% [markdown]
# # Running the A3C with custom envornments

# %%
# Initial arguments
class Args ():
    
    def __init__(self):
        self.algorithm='a3c' #random or a3c
        self.lr=0.001
        self.max_eps=500
        self.gamma=0.99
        self.save_dir='results'
        self.update_freq = 20
        self.env_name = 'CartPole-v0'
args = Args()

# %%
# %run a3c.ipynb
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
master = MasterAgent()
# Out:
# 4 2
# /anaconda3/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %%
master.train()
# Out:
# /anaconda3/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# Starting worker 0
# Starting worker 1
# Starting worker 2
# Starting worker 3
# Episode: 0 | Moving Average Reward: 17 | Episode Reward: 17 | Loss: 2.608 | Steps: 18 | Worker: 2
# Saving best model to results, episode score: 17.0
# Episode: 0 | Moving Average Reward: 12 | Episode Reward: 12 | Loss: 1.887 | Steps: 13 | Worker: 3
# Saving best model to results, episode score: 12.0
# Episode: 2 | Moving Average Reward: 12 | Episode Reward: 25 | Loss: 3.04 | Steps: 26 | Worker: 1
# Saving best model to results, episode score: 25.0
# Episode: 3 | Moving Average Reward: 12 | Episode Reward: 31 | Loss: 2.9 | Steps: 32 | Worker: 0
# Saving best model to results, episode score: 31.0
# Episode: 4 | Moving Average Reward: 12 | Episode Reward: 12 | Loss: 1.932 | Steps: 13 | Worker: 3
# ...

# %%
master.play()
# Out:
# /anaconda3/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# Loading model from: results/model_CartPole-v0.h5
# 0. Reward: 1.0, action: 1
# 1. Reward: 2.0, action: 1
# 2. Reward: 3.0, action: 0
# 3. Reward: 4.0, action: 0
# 4. Reward: 5.0, action: 0
# 5. Reward: 6.0, action: 1
# 6. Reward: 7.0, action: 0
# 7. Reward: 8.0, action: 1
# 8. Reward: 9.0, action: 1
# 9. Reward: 10.0, action: 0
# 10. Reward: 11.0, action: 1
# 11. Reward: 12.0, action: 1
# 12. Reward: 13.0, action: 0
# 13. Reward: 14.0, action: 1
# 14. Reward: 15.0, action: 0
# 15. Reward: 16.0, action: 0
# 16. Reward: 17.0, action: 1
# 17. Reward: 18.0, action: 0
# 18. Reward: 19.0, action: 0
# 19. Reward: 20.0, action: 1
# 20. Reward: 21.0, action: 1
# 21. Reward: 22.0, action: 0
# 22. Reward: 23.0, action: 0
# 23. Reward: 24.0, action: 0
# 24. Reward: 25.0, action: 1
# ...

# %%
master.random()
